# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedhossny4654/BloodCell/blob/main/Blood_Cell_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#first import the library that i will use 
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
from skimage import color
from skimage.filters import gaussian
from skimage import exposure
from skimage import transform

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# this step to import data
photo=plt.imread('/content/drive/MyDrive/dataset-master/dataset-master/JPEGImages/BloodImage_00000.jpg')

# %%
red=photo[:,:,0]
plt.hist(red.ravel(),bins=256)
# Out:
# (array([1.000e+00, 1.000e+00, 0.000e+00, 5.000e+00, 0.000e+00, 2.000e+01,
#         0.000e+00, 3.100e+01, 0.000e+00, 5.800e+01, 0.000e+00, 6.700e+01,
#         0.000e+00, 5.200e+01, 0.000e+00, 4.900e+01, 0.000e+00, 4.200e+01,
#         0.000e+00, 5.400e+01, 0.000e+00, 4.800e+01, 5.000e+01, 0.000e+00,
#         5.800e+01, 0.000e+00, 4.900e+01, 0.000e+00, 7.900e+01, 0.000e+00,
#         8.300e+01, 0.000e+00, 8.200e+01, 0.000e+00, 1.360e+02, 0.000e+00,
#         1.690e+02, 0.000e+00, 2.030e+02, 0.000e+00, 1.910e+02, 0.000e+00,
#         2.160e+02, 2.400e+02, 0.000e+00, 2.380e+02, 0.000e+00, 3.120e+02,
#         0.000e+00, 2.960e+02, 0.000e+00, 3.110e+02, 0.000e+00, 3.530e+02,
#         0.000e+00, 3.720e+02, 0.000e+00, 4.040e+02, 0.000e+00, 4.590e+02,
#         0.000e+00, 5.310e+02, 0.000e+00, 6.090e+02, 6.300e+02, 0.000e+00,
#         6.500e+02, 0.000e+00, 7.400e+02, 0.000e+00, 7.560e+02, 0.000e+00,
#         7.480e+02, 0.000e+00, 7.820e+02, 0.000e+00, 7.810e+02, 0.000e+00,
# ...

# %%
#to see the size of photo
photo.shape
# Out:
# (480, 640, 3)

# %% [markdown]
# ## showing pic

# %%
#here to show the data 
plt.imshow(photo);

# %%
#to  see the Red value of this matrix   
photo[:,:,0]
plt.imshow(photo[:,:,0])

# %%
#to  see the Green value of this matrix    in this case is clean better tyhan blue and red
photo[:,:,1]
plt.imshow(photo[:,:,1])

# %%
#to  see the Blue value of this matrix    worest type 
photo[:,:,2]
plt.imshow(photo[:,:,2])

# %%
#grayscale
grayscale = color.rgb2gray(photo)
plt.imshow(grayscale)

# %% [markdown]
# ##**Resize the pics And some edits**`

# %%
#in this step can i change the size of pic and this is very step 
height=7000
width=3000
image_resize=transform.resize(photo,( height, width),anti_aliasing=True)
plt.imshow(image_resize)

# %%
#in this step will rotate he pic 
image=transform.rotate(photo,90)
plt.imshow(image)

# %%
#here we start to flippening the pic
photo_flip=np.flipud(photo)
plt.imshow(photo_flip);

# %%
# in this step  flipp the pic but it will 
#be herzonal it not will be down or up  it will from left to right or diff
photo_flip_hoizontally=np.fliplr(photo)
plt.imshow(photo_flip_hoizontally);

# %% [markdown]
# ## **binary grayscale**

# %%
threshold=0.5
grayscale_binary=grayscale>threshold
plt.imshow(grayscale_binary)

# %%
from skimage import filters

# %%
from skimage.filters import threshold_otsu

# %%
plt.hist(grayscale.ravel(),bins=256)
# Out:
# (array([2.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 3.000e+00, 2.000e+00, 4.000e+00, 9.000e+00, 6.000e+00,
#         9.000e+00, 1.600e+01, 3.100e+01, 5.200e+01, 7.900e+01, 5.900e+01,
#         5.900e+01, 4.200e+01, 5.800e+01, 5.700e+01, 5.300e+01, 6.900e+01,
#         7.000e+01, 6.900e+01, 8.400e+01, 8.400e+01, 8.200e+01, 8.700e+01,
#         8.000e+01, 8.800e+01, 1.190e+02, 9.900e+01, 1.690e+02, 1.370e+02,
#         2.060e+02, 1.830e+02, 1.940e+02, 2.210e+02, 2.050e+02, 2.960e+02,
#         2.600e+02, 3.260e+02, 2.830e+02, 3.000e+02, 3.370e+02, 3.490e+02,
#         3.800e+02, 3.950e+02, 4.450e+02, 4.900e+02, 6.210e+02, 5.950e+02,
#         7.330e+02, 8.130e+02, 9.680e+02, 1.230e+03, 1.303e+03, 1.607e+03,
#         1.608e+03, 1.732e+03, 1.759e+03, 1.671e+03, 2.172e+03, 2.108e+03,
#         2.333e+03, 2.416e+03, 2.739e+03, 2.927e+03, 3.077e+03, 3.707e+03,
#         3.469e+03, 3.953e+03, 3.259e+03, 3.248e+03, 3.190e+03, 2.856e+03,
# ...

# %%
#in this step remove the third Dimention (3) it before was (480,640,3)
grayscale_binary.shape
# Out:
# (480, 640)

# %%
#here want to see the size of this pic >>>> the result will be 480*640
photo.size
# Out:
# 921600

# %% [markdown]
# ## **first filter gaussian**

# %%
#new feature in filter it like plureing in the pic 
photo_filtered= gaussian(photo,sigma=3)
plt.imshow(photo_filtered)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.

# %% [markdown]
# ## **second  Exposure filter**

# %%
#new feature  called exposure its like show the degree of color 
image_eq = exposure.equalize_hist(photo)
plt.imshow(image_eq)
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/exposure/exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)

# %%
image_eq1 = exposure.equalize_adapthist(photo)
plt.imshow(image_eq1)

# %%
plt.hist(image_eq1.ravel(),bins=256)
# Out:
# (array([3.0000e+00, 6.0000e+00, 6.0000e+00, 1.0000e+01, 1.8000e+01,
#         3.2000e+01, 4.4000e+01, 5.9000e+01, 4.6000e+01, 5.6000e+01,
#         6.0000e+01, 5.0000e+01, 6.2000e+01, 7.5000e+01, 8.6000e+01,
#         7.1000e+01, 7.2000e+01, 1.1200e+02, 8.6000e+01, 9.3000e+01,
#         1.1700e+02, 1.2300e+02, 1.0100e+02, 1.1700e+02, 1.2400e+02,
#         1.2200e+02, 1.3900e+02, 1.7600e+02, 1.8500e+02, 2.0200e+02,
#         2.1700e+02, 2.4000e+02, 2.7100e+02, 3.0600e+02, 3.5400e+02,
#         3.6800e+02, 3.8800e+02, 5.0400e+02, 5.0600e+02, 4.9100e+02,
#         6.6700e+02, 6.5300e+02, 7.5800e+02, 8.5900e+02, 8.7400e+02,
#         9.7900e+02, 1.0530e+03, 1.2720e+03, 1.4180e+03, 1.4560e+03,
#         1.8070e+03, 1.8830e+03, 2.0460e+03, 2.3970e+03, 2.7130e+03,
#         2.9190e+03, 3.2530e+03, 3.9820e+03, 3.9600e+03, 4.4780e+03,
#         4.7250e+03, 5.3000e+03, 5.3140e+03, 5.9360e+03, 6.5750e+03,
#         6.5990e+03, 6.7980e+03, 6.9830e+03, 7.1510e+03, 7.2380e+03,
# ...

# %% [markdown]
# ## third filter
